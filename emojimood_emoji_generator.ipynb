# %% [markdown]
# <a href="https://colab.research.google.com/github/zehra44/Project/blob/main/emojimood_emoji_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers  #creates the pipline
# !pip install torch

# %%
from transformers import pipeline
import random

# %%
#Load Hugging face pipeline for sentiment analysis
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
#Mapping based on detected sentiment
emoji_dict= {
    "POSITIVE":["😄", "😁", "😊", "🥰", "🤩", "😍", "❤️", "👍"],
    "NEGATIVE":["😢", "😭", "😠", "😡", "💔", "👎"],
    "NEUTRAL": ["😐", "😶", "🤔", "😑"]
}

keyword_emoji = {
    "happy": ["😊", "😁", "🥳"],
    "love": ["❤️", "😍", "💕"],
    "angry": ["😡", "😠", "🤬"],
    "sad": ["😢", "😭", "💔"],
    "fun": ["😆", "🎉", "🥳"],
    "excited": ["🤩", "🎉", "😃"]
}

# %%
def generate_emojis(text, num_sentiment_emojis=2):
    # Get sentiment prediction
    result = sentiment_pipeline(text)[0]
    label = result['label']

    # Get sentiment emojis
    sentiment_emojis = random.sample(
        emoji_dict.get(label, ["🙂"]),
        min(num_sentiment_emojis, len(emoji_dict.get(label, [])))
    )

    # Get keyword-based emojis
    keyword_emojis = []
    for keyword in keyword_emoji:
        if keyword in text.lower():
            keyword_emojis.extend(keyword_emoji[keyword])

    # Merge & remove duplicates
    all_emojis = list(set(sentiment_emojis + keyword_emojis))

    return " ".join(all_emojis)

# %%
text = "I am very happy today because i won the match"
emojis = generate_emojis(text)

print("input text:",text)
print("Generated emojis:",emojis)
# Out:
# input text: I am very happy today because i won the match
# Generated emojis: 🥳 🤩 😊 😁

# %%
# !pip install gradio
import gradio as gr

# %%
def emoji_ui(text):
  return generate_emojis(text)

gr.Interface(fn=emoji_ui,inputs="text",outputs="text",title="EmojiMood-Emoji Generator").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1755cbf237253fbd19.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1755cbf237253fbd19.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
