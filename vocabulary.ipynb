# %% [markdown]
# <a href="https://colab.research.google.com/github/zehra44/Project/blob/main/vocabulary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
documents = ["I love machine learning.","Machine learning is amazing."]

# %%
vectorizer = CountVectorizer(lowercase=True,stop_words='english')

# %%
x = vectorizer.fit_transform(documents)

# %%
print("Vocabulary:",vectorizer.get_feature_names_out())
# Out:
# Vocabulary: ['amazing' 'learning' 'love' 'machine']

# %%
print("Word Count Vectors:\n",x.toarray())
# Out:
# Word Count Vectors:
#  [[0 1 1 1]
#  [1 1 0 1]]
